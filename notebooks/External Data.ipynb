# %%
import os
from glob import glob
from PIL import Image

# %%
EXTERNAL = '../external/All-Age-Faces Dataset/original images'
img = glob(os.path.join(EXTERNAL, '*'))[3]
name = os.path.basename(img)
name
# Out:
# '10665A37.jpg'

# %%
Image.open(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=302x339 at 0x7F670C386B50>
